# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
df = pd.read_csv('Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df = df.drop(('Species'), axis=1)
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
# [150 rows x 5 columns]

# %%
# if we do not specify the attributes collecton by default the attribute selection measeure is gene index

# %%
model= DecisionTreeClassifier(criterion='gini')

# %%
gini_impurities = ()

# %%
df.shape
# Out:
# (150, 5)

# %%
df.shape[1]
# Out:
# 5

# %%
# Reshape command in numpy is used to reshape our numpy array

# %%
import numpy as np
arr = np.array([1,2,3,4,5,6])
print('ORIGINAL SHAPE',arr.shape)

reshaped_arr= arr.reshape(-1,1)
print('RESHAPED SHAPE',reshaped_arr.shape)
# Out:
# ORIGINAL SHAPE (6,)
# RESHAPED SHAPE (6, 1)

# %%
# When we Reshadding the array then the number of rows and columns shall be a factor oftotal number of elements present in the array....

# %%
reshaped_arr = arr.reshape(2,3)
print("reshaped array shape", reshaped_arr.shape)
print(reshaped_arr)
# Out:
# reshaped array shape (2, 3)
# [[1 2 3]
#  [4 5 6]]

# %%
reshaped_arr = arr.reshape(1,6)
print("reshaped array shape", reshaped_arr.shape)
print(reshaped_arr)
# Out:
# reshaped array shape (1, 6)
# [[1 2 3 4 5 6]]

# %%
reshaped_arr = arr.reshape(6,1)
print("reshaped array shape", reshaped_arr.shape)
print(reshaped_arr)
# Out:
# reshaped array shape (6, 1)
# [[1]
#  [2]
#  [3]
#  [4]
#  [5]
#  [6]]

# %%
reshaped_arr[:,0]
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
#array([1,4])
#for i in range(df.shape[i]):
 # model = model.fit(df.iloc[:,i].values.reshape(-1,1)),y
  #prob = model.predict_proba(df.iloc[:,i].values.reshape(-1,1))
 # gini_impurities[i] = 1- (prob[:,0]**2 + prob[:,2]**2).sum()

# %%
import numpy as np

np.array([1,4])
for i in range(df.shape[1]):
  model = model.fit(df.iloc[:,i].values.reshape(-1,1),y)
  prob = model.predict_proba(df.iloc[:,i].values.reshape(-1,1))
  gini_impurities[i] = 1- (prob[:,0]**2 + prob[:,1]**2).sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-177-1d342197cf1c> in <cell line: 4>()
#       3 np.array([1,4])
#       4 for i in range(df.shape[1]):
# ----> 5   model = model.fit(df.iloc[:,i].values.reshape(-1,1))
#       6   prob = model.predict_proba(df.iloc[:,i].values.reshape(-1,1))
#       7   gini_impurities[i] = 1- (prob[:,0]**2 + prob[:,1]**2).sum()
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#    1474
#    1475         return wrapper
#
# TypeError: DecisionTreeClassifier.fit() missing 1 required positional argument: 'y'

# %%
best_feature = min(gini_impurities, key=gini_impurities.get)
print(f"Best feature: (best_feature)")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-174-9f56dfee364a> in <cell line: 1>()
# ----> 1 best_feature = min(gini_impurities, key=gini_impurities.get)
#       2 print(f"Best feature: (best_feature)")
#
# AttributeError: 'tuple' object has no attribute 'get'

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
plt.figure(figsize=(15,10))
plot_tree(model, filled=True)
plt.tittle('Original Decision Tree')
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
df = pd.read_csv('User_Data.csv')
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]
