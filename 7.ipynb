# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier.plot_tree
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
df = pd.read_csv('User_Data.csv')
df
classification_report
# Out:
#   File "<ipython-input-2-1840a028b1ba>", line 3
#     from sklearn.tree import DecisionTreeClassifier.plot_tree
#                                                    ^
# SyntaxError: invalid syntax

# %%
x_train,y_train,x_test,y_test=train_test_split(x,y,test_size=0.25,random_state=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ab23e12bbd5f> in <cell line: 1>()
# ----> 1 x_train,y_train,x_test,y_test=train_test_split(x,y,test_size=0.25,random_state=0)
#
# NameError: name 'train_test_split' is not defined

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e1f4aed98479> in <cell line: 3>()
#       1 from sklearn.preprocessing import StandardScaler
#       2 sc = StandardScaler()
# ----> 3 x_train = sc.fit_transform(x_train)
#       4 x_test = sc.transform(x_test)
#       5
#
# NameError: name 'x_train' is not defined
